# %%
import pandas as pd

# %%
filename = 'us-airports.csv'

imported_data = pd.read_csv(filename)

# %%
imported_data.head()
# Out:
#      id ident           type  \
# 0  3632  KLAX  large_airport
# 1  3754  KORD  large_airport
# 2  3622  KJFK  large_airport
# 3  3384  KATL  large_airport
# 4  3878  KSFO  large_airport
#
#                                                name  latitude_deg  \
# 0                 Los Angeles International Airport     33.942501
# 1              Chicago O'Hare International Airport     41.978600
# 2              John F Kennedy International Airport     40.639447
# 3  Hartsfield Jackson Atlanta International Airport     33.636700
# 4               San Francisco International Airport     37.619806
#
#    longitude_deg  elevation_ft continent   country_name iso_country  ...  \
# 0    -118.407997         125.0       NaN  United States          US  ...
# 1     -87.904800         680.0       NaN  United States          US  ...
# 2     -73.779317          13.0       NaN  United States          US  ...
# 3     -84.428101        1026.0       NaN  United States          US  ...
# ...

# %%
usa_iata_codes = imported_data['ident'].unique()
usa_iata_codes.sort()
print(usa_iata_codes)
# Out:
# ['00A' '00AA' '00AK' ... 'Z95' 'ZNC' 'ZZ-0003']

# %%
# codes_w_prefix = [('K' + code).upper() for code in usa_iata_codes]
# codes_w_prefix.sort()
# print(codes_w_prefix)
# Out:
# ['KABE', 'KABI', 'KABQ', 'KABR', 'KABY', 'KACK', 'KACT', 'KACV', 'KACY', 'KADQ', 'KAEX', 'KAGS', 'KAHN', 'KAIA', 'KAKN', 'KALB', 'KALO', 'KALS', 'KALW', 'KAMA', 'KANC', 'KAOO', 'KAPF', 'KAPN', 'KART', 'KASE', 'KATL', 'KATW', 'KATY', 'KAUG', 'KAUS', 'KAVL', 'KAVP', 'KAZO', 'KBBF', 'KBDL', 'KBED', 'KBET', 'KBFF', 'KBFL', 'KBGM', 'KBGR', 'KBHB', 'KBHM', 'KBIG', 'KBIL', 'KBIS', 'KBJI', 'KBKW', 'KBKX', 'KBLF', 'KBLI', 'KBMG', 'KBMI', 'KBNA', 'KBOI', 'KBOS', 'KBPT', 'KBQK', 'KBRL', 'KBRO', 'KBRW', 'KBTM', 'KBTR', 'KBTT', 'KBTV', 'KBUF', 'KBUR', 'KBWI', 'KBZN', 'KCAE', 'KCAK', 'KCDV', 'KCEF', 'KCGI', 'KCHA', 'KCHI', 'KCHO', 'KCHS', 'KCIC', 'KCID', 'KCIU', 'KCKB', 'KCLD', 'KCLE', 'KCLL', 'KCLT', 'KCLU', 'KCMH', 'KCMI', 'KCMX', 'KCNM', 'KCOD', 'KCOS', 'KCOU', 'KCPR', 'KCRP', 'KCRW', 'KCSG', 'KCVG', 'KCVN', 'KCWA', 'KCYS', 'KDAB', 'KDAL', 'KDAY', 'KDBQ', 'KDCA', 'KDDC', 'KDEC', 'KDEN', 'KDFW', 'KDHN', 'KDIK', 'KDLG', 'KDLH', 'KDRO', 'KDSM', 'KDTT', 'KDTW', 'KDUJ', 'KDUT', 'KDVL', 'KEAR', 'KEAT
# ...

# %%
with open('us_airport_codes.txt', 'w') as file:
    for code in usa_iata_codes:
        file.write(code + '\n')
